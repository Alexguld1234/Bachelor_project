# %%
import pandas as pd
df = pd.read_csv("data/mimic-cxr-2.0.0-metadata.csv")

# %%
df.head(10)
# Out:
#                                        dicom_id  subject_id  study_id  \
# 0  02aa804e-bde0afdd-112c0b34-7bc16630-4e384014    10000032  50414267
# 1  174413ec-4ec4c1f7-34ea26b7-c5f994f8-79ef1962    10000032  50414267
# 2  2a2277a9-b0ded155-c0de8eb9-c124d10e-82c5caab    10000032  53189527
# 3  e084de3b-be89b11e-20fe3f9f-9c8d8dfe-4cfd202c    10000032  53189527
# 4  68b5c4b1-227d0485-9cc38c3f-7b84ab51-4b472714    10000032  53911762
# 5  fffabebf-74fd3a1f-673b6b41-96ec0ac9-2ab69818    10000032  53911762
# 6  ea030e7a-2e3b1346-bc518786-7a8fd698-f673b44c    10000032  56699142
# 7  096052b7-d256dc40-453a102b-fa7d01c6-1b22c6b4    10000764  57375967
# 8  b79e55c3-735ce5ac-64412506-cdc9ea79-f1af521f    10000764  57375967
# 9  dcfeeac4-1597e318-d0e6736a-8b2c2238-47ac3f1b    10000764  57375967
#
#   PerformedProcedureStepDescription ViewPosition  Rows  Columns  StudyDate  \
# 0                CHEST (PA AND LAT)           PA  3056     2544   21800506
# ...

# %%
df.shape, df.columns
# Out:
# ((377110, 12),
#  Index(['dicom_id', 'subject_id', 'study_id',
#         'PerformedProcedureStepDescription', 'ViewPosition', 'Rows', 'Columns',
#         'StudyDate', 'StudyTime', 'ProcedureCodeSequence_CodeMeaning',
#         'ViewCodeSequence_CodeMeaning',
#         'PatientOrientationCodeSequence_CodeMeaning'],
#        dtype='object'))

# %%
for column in df.columns:
    print(f"Column: {column}")
    print(df[column].value_counts())  # Print first 5 values in each column
    print("-" * 40)  # Separator for readability
# Out:
# Column: dicom_id
# dicom_id
# 1a1fe7e3-cbac5d93-b339aeda-86bb86b5-4f31e82e    1
# 02aa804e-bde0afdd-112c0b34-7bc16630-4e384014    1
# 174413ec-4ec4c1f7-34ea26b7-c5f994f8-79ef1962    1
# 2a2277a9-b0ded155-c0de8eb9-c124d10e-82c5caab    1
# e084de3b-be89b11e-20fe3f9f-9c8d8dfe-4cfd202c    1
#                                                ..
# 0c4eb1e1-b801903c-bcebe8a4-3da9cd3c-3b94a27c    1
# dcfeeac4-1597e318-d0e6736a-8b2c2238-47ac3f1b    1
# b79e55c3-735ce5ac-64412506-cdc9ea79-f1af521f    1
# 096052b7-d256dc40-453a102b-fa7d01c6-1b22c6b4    1
# ea030e7a-2e3b1346-bc518786-7a8fd698-f673b44c    1
# Name: count, Length: 377110, dtype: int64
# ----------------------------------------
# Column: subject_id
# subject_id
# 16454913    174
# 16662316    169
# 12043836    167
# 19133405    157
# 15936063    142
#            ...
# 19145636      1
# 19145070      1
# 13765791      1
# 19146254      1
# 19145854      1
# Name: count, Length: 65379, dtype: int64
# ...

# %%
df.isnull().sum()  # Count missing values per column
# Out:
# dicom_id                                          0
# subject_id                                        0
# study_id                                          0
# PerformedProcedureStepDescription             35512
# ViewPosition                                  15769
# Rows                                              0
# Columns                                           0
# StudyDate                                         0
# StudyTime                                         0
# ProcedureCodeSequence_CodeMeaning                 0
# ViewCodeSequence_CodeMeaning                  16497
# PatientOrientationCodeSequence_CodeMeaning    41166
# dtype: int64

# %%
df["ViewPosition"].value_counts()  # Replace 'column_name' with actual column name
# Out:
# ViewPosition
# AP                147173
# PA                 96161
# LATERAL            82853
# LL                 35133
# PA LLD                 4
# LAO                    3
# RAO                    3
# AP AXIAL               2
# AP LLD                 2
# XTABLE LATERAL         2
# AP RLD                 2
# SWIMMERS               1
# PA RLD                 1
# LPO                    1
# Name: count, dtype: int64

# %%
# Example: Get all rows where 'viewposition' is 'AP' and select values from 'column_name'
filtered_values = df[df["ViewPosition"] == "AP"]["subject_id"].value_counts()
print(filtered_values)
# Out:
# subject_id
# 16454913    167
# 12043836    133
# 18295542    131
# 15936063    129
# 17277688    109
#            ...
# 10001122      1
# 19985469      1
# 19995593      1
# 19995780      1
# 19990757      1
# Name: count, Length: 33501, dtype: int64

# %%
k = 35  # Number of rows you want
filtered_rows = df[df["ViewPosition"] == "AP"].head(k)
print(filtered_rows)
# Out:
#                                          dicom_id  subject_id  study_id  \
# 4    68b5c4b1-227d0485-9cc38c3f-7b84ab51-4b472714    10000032  53911762
# 5    fffabebf-74fd3a1f-673b6b41-96ec0ac9-2ab69818    10000032  53911762
# 6    ea030e7a-2e3b1346-bc518786-7a8fd698-f673b44c    10000032  56699142
# 7    096052b7-d256dc40-453a102b-fa7d01c6-1b22c6b4    10000764  57375967
# 15   d0b71acc-b5a62046-bbb5f6b8-7b173b85-65cdf738    10000935  50578979
# 17   9b314ad7-fbcb0422-6db62dfc-732858d0-a5527d8b    10000935  51178377
# 20   8e3f2822-0c1d4b71-2a265bbf-5b96e531-ccf5fa30    10000935  56164612
# 24   88498b37-c21dc7ba-bc202800-b517a62d-f7ac5bcf    10000935  58219844
# 27   943486a3-b3fa9ff7-50f5a769-7a62fcbb-f39b6da4    10000980  51967283
# 29   cfb03587-782edf6c-1bf392e1-98196cd5-365d69e8    10000980  54577367
# 32   a75a1fbe-802065ad-717eb7c1-e2ce3552-646276a6    10000980  54980801
# 36   54affd39-8bf24209-232bac8a-df6c277a-398ee8a5    10000980  58206436
# ...
